# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
from pandas_datareader.data import DataReader
from datetime import datetime

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.04321808],
#        [0.04405767],
#        [0.04379238],
#        ...,
#        [0.94730502],
#        [0.95502302],
#        [0.96332786]])

# %%
df.to_csv('news_headline.csv', index=False)

# %%
DF=df
DF
# Out:
#            date                                           headline
# 0      20010125  Kumble's absence may encourage youngsters: Dravid
# 1      20010125  CBSE evinces interest in UT weekly tests progr...
# 2      20010213   Indo-Fijian Hindus observe festival with fervour
# 3      20010226                    NTPC may curtail supply to BSEB
# 4      20010323             Rollercoaster: Sensex moves southwards
# ...         ...                                                ...
# 16954  20200629  CBSE's assessment scheme for nixed exams cause...
# 16955  20200630  No exams for UBSE students residing in contain...
# 16956  20200630     50% KGBV staff found absent in random checking
# 16957  20200630    Last RBSE exam today; results likely by July 15
# 16958  20200630             cbse course cut to impact jee neet too
#
# [16959 rows x 2 columns]

# %%
l=[]
for i in range(len(DF)):
    if "S&P" in DF["headline"][i].upper() or "SENSEX" in DF["headline"][i].upper():
        l.append([DF["date"][i],DF["headline"][i]])

# %%
DF=pd.read_csv("news_headline.csv")
DF.head(20)
# Out:
#         date                                          headline
# 0   20010323            Rollercoaster: Sensex moves southwards
# 1   20010407                          Sensex sheds early gains
# 2   20010411   Sensex under bear attack; drops to 23-month low
# 3   20010412   Sensex nosedives as Infy hints at tech slowdown
# 4   20010418     Sensex rises 61 points despite Infy-Sify drag
# 5   20010529    Sensex stays in the bull zone; gains 60 points
# 6   20010715        MONEY WISE brSensex faces a roller coaster
# 7   20010727                  For Sensex; worst is yet to come
# 8   20010729                     Sensex faces a roller-coaster
# 9   20010804           Sensex recovers by 2.27% over last week
# 10  20010807                        Sensex slides by 11 points
# 11  20010807          S&P downgrade seen to have little impact
# 12  20010808         S&P's downgrading attracts mixed reaction
# 13  20010808         S&P downgrade will affect FDI; divestment
# ...

# %%
scores = DF['headline'].apply(vader.polarity_scores)
scores_df = pd.DataFrame.from_records(scores)

# %%
DF=DF.join(scores_df)
DF
# Out:
#           date                                           headline    neg  \
# 0     20010323             Rollercoaster: Sensex moves southwards  0.000
# 1     20010407                           Sensex sheds early gains  0.000
# 2     20010411    Sensex under bear attack; drops to 23-month low  0.834
# 3     20010412    Sensex nosedives as Infy hints at tech slowdown  0.000
# 4     20010418      Sensex rises 61 points despite Infy-Sify drag  0.000
# ...        ...                                                ...    ...
# 7110  20200602  Sensex rallies 9% in 4 days as RIL; financial ...  0.000
# 7111  20200603           D-St ignores rating action; sensex gains  0.123
# 7112  20200617  D-Street discounts border clash; sensex ends i...  0.000
# 7113  20200622  Sensex up 34% on handful of stocks since March...  0.550
# 7114  20200627      Axis Bank loses S&P's investment grade rating  0.277
#
#         neu    pos  compound
# 0     1.000  0.000    0.0000
# 1     0.214  0.786    0.9325
# ...

# %%
import plotly.express as px
fig = px.line(DF, x="date", y="compound")
fig.show()
# Out:
# <div>
#
#
#             <div id="5666ee31-e311-4d27-98ba-d27cadb55b01" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5666ee31-e311-4d27-98ba-d27cadb55b01")) {
#                     Plotly.newPlot(
#                         '5666ee31-e311-4d27-98ba-d27cadb55b01',
# ...
