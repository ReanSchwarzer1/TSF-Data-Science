# %% [markdown]
# ## Adhiraj Bhagawati

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Importing the necessary libraries into the notebook

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fa524562-1061-4625-83ae-0bd9d8df375f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa524562-1061-4625-83ae-0bd9d8df375f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleSuperstore.csv to SampleSuperstore.csv
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head(10)
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
# 5  Standard Class   Consumer  United States  ...        7     0.00   14.1694
# 6  Standard Class   Consumer  United States  ...        4     0.00    1.9656
# 7  Standard Class   Consumer  United States  ...        6     0.20   90.7152
# 8  Standard Class   Consumer  United States  ...        3     0.20    5.7825
# 9  Standard Class   Consumer  United States  ...        5     0.00   34.4700
#
# [10 rows x 13 columns]

# %%
df.drop('Country', axis=1, inplace=True)
df.head()
# Out:
#         Ship Mode    Segment             City  ... Quantity  Discount    Profit
# 0    Second Class   Consumer        Henderson  ...        2      0.00   41.9136
# 1    Second Class   Consumer        Henderson  ...        3      0.00  219.5820
# 2    Second Class  Corporate      Los Angeles  ...        2      0.00    6.8714
# 3  Standard Class   Consumer  Fort Lauderdale  ...        5      0.45 -383.0310
# 4  Standard Class   Consumer  Fort Lauderdale  ...        2      0.20    2.5164
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (9994, 12)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df['Quantity'].count()
sns.set()

# %%
num_bins = 8
plt.hist(df['Ship Mode'], num_bins, facecolor ='grey' , alpha = 0.8)
plt.show()

# %%
# Segment
num_bins = 8
plt.hist(df['Segment'], num_bins, facecolor ='purple' , alpha = 0.9)
plt.show()

# %%
# Postal Code
num_bins = 30
plt.hist(df['Postal Code'], num_bins, facecolor ='black' , alpha = 0.8)
plt.show()

# %%
# Category
num_bins = 8
plt.hist(df['Category'], num_bins, facecolor ='blue' , alpha = 0.8)
plt.show()

# %%
# Discount
num_bins = 15
plt.hist(df['Discount'], num_bins, facecolor ='cyan' , alpha = 0.8)
plt.show()

# %%
num_bins = 30
plt.hist(df['Postal Code'], num_bins, facecolor ='red' , alpha = 0.8)
plt.show()

# %% [markdown]
# Regional Sales

# %%
sales_by_region = df.groupby('Region').size()
print(sales_by_region)
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# dtype: int64

# %%
plot_by_region = sales_by_region.plot(title='Sales by Region',xticks=(1,2,3,4))
plot_by_region.set_xlabel('Region')
plot_by_region.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# Sales by Profit

# %%
sales_by_profit = df.groupby('Profit').size()
print(sales_by_profit)

plot_by_profit = sales_by_profit.plot(title='Sales by Profit', xticks = range(0, 30))
plot_by_profit.set_xlabel('Profit')
plot_by_profit.set_ylabel('Sales')
# Out:
# Profit
# -6599.9780    1
# -3839.9904    1
# -3701.8928    1
# -3399.9800    1
# -2929.4845    1
#              ..
#  4630.4755    1
#  4946.3700    1
#  5039.9856    1
#  6719.9808    1
#  8399.9760    1
# Length: 7287, dtype: int64
# Text(0, 0.5, 'Sales')

# %% [markdown]
# Categorical Sales

# %%
sales_by_category = df.groupby('Category').size()
print(sales_by_category)

plot_by_category = sales_by_category.plot(title='Sales by Category')
plot_by_category.set_xlabel('Category')
plot_by_category.set_ylabel('Sales')
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Sales by Ship Mode

# %%
sales_by_shipmode = df.groupby('Ship Mode').size()
print(sales_by_shipmode)

sales_by_shipmode = sales_by_shipmode.plot(title='Sales by Ship Mode')
sales_by_shipmode.set_xlabel('Ship Mode')
sales_by_shipmode.set_ylabel('Sales')
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# dtype: int64
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Sales by Segment

# %%
sales_by_segment = df.groupby('Segment').size()
print(sales_by_segment)

sales_by_segment = sales_by_segment.plot(title='Sales by Segment')
sales_by_segment.set_xlabel('Segment')
sales_by_segment.set_ylabel('Sales')
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# dtype: int64
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Distribution of Quantity v/s Sales

# %%
# Plotting the distribution of Quantity v/s Sales
df.plot(x='Quantity', y='Sales', style='o')
plt.title('Quantity vs Sales')  
plt.xlabel('Quantity')  
plt.ylabel('Sales')  
plt.show()

# %% [markdown]
# ### Distribution of Discount v/s Sales

# %%
# Plotting the distribution of Discount v/s Sales
df.plot(x='Discount', y='Sales', style='>')
plt.title('Discount vs Sales')  
plt.xlabel('Discount')  
plt.ylabel('Sales')  
plt.show()

# %% [markdown]
# ### Distribution of Discount v/s Profit

# %%
# Plotting the distribution of Discount
df.plot(x='Profit', y='Sales', style='^')
plt.title('Discount vs Profit')  
plt.xlabel('Discount')  
plt.ylabel('Profit')  
plt.show()
